# %%
import pandas as pd 
from matplotlib import pyplot as plt
import numpy as np
from bokeh.plotting import figure, output_notebook, show

# %%
Philippines_MM = pd.read_csv (r'Philippines_MM.csv')
Philippines_MM.drop(['Country_code', 'Country', 'WHO_region','New_cases','New_deaths','Cumulative_deaths'], 
                    axis='columns',  inplace=True)
Philippines_MM = pd.DataFrame(Philippines_MM)
Philippines_MM['Days_reported'] = Philippines_MM.index
Philippines_MM
# Out:
#     Date_reported  Cumulative_cases  Days_reported
# 0        1/3/2020                 0              0
# 1        1/4/2020                 0              1
# 2        1/5/2020                 0              2
# 3        1/6/2020                 0              3
# 4        1/7/2020                 0              4
# ..            ...               ...            ...
# 622     9/16/2021           2282931            622
# 623     9/17/2021           2304139            623
# 624     9/18/2021           2324416            624
# 625     9/19/2021           2347478            625
# 626     9/20/2021           2366749            626
#
# [627 rows x 3 columns]

# %%
Philippines_MM_filtered = Philippines_MM[(Philippines_MM["Cumulative_cases"] >= 1) & (Philippines_MM["Cumulative_cases"] <= 100)]
Philippines_MM_filtered_1 = Philippines_MM[(Philippines_MM["Cumulative_cases"] >= 1) & (Philippines_MM["Cumulative_cases"] <= 500)]

# %%
p = figure(title="Raw Data For Philippines",width=800, height=400)
# add a line renderer
p.line(Philippines_MM['Days_reported'],Philippines_MM['Cumulative_cases'],line_width=2)
p.xaxis.axis_label = "Days From Begining"
p.yaxis.axis_label = "Cumulative Cases"

p.title.align = "center"
p.title.text_color = "white"
show(p)

# %%
Afghanistan_MM = pd.read_csv (r'Afghanistan_MM.csv')
Afghanistan_MM.drop(['Country_code', 'Country', 'WHO_region','New_cases','New_deaths','Cumulative_deaths'], 
                    axis='columns',  inplace=True)
Afghanistan_MM = pd.DataFrame(Afghanistan_MM)

Afghanistan_MM['Days_reported'] = Afghanistan_MM.index

# %%
Afghanistan_MM_filtered = Afghanistan_MM[(Afghanistan_MM["Cumulative_cases"] >= 1) & (Afghanistan_MM["Cumulative_cases"] <= 100)]
Afghanistan_MM_filtered_1 = Afghanistan_MM[(Afghanistan_MM["Cumulative_cases"] >= 1) & (Afghanistan_MM["Cumulative_cases"] <= 500)]

# %%
# create figure
p = figure(title="Raw Data For Afghanistan",plot_width = 800, plot_height = 400)
   
# add a line renderer
p.line(Afghanistan_MM['Days_reported'], Afghanistan_MM['Cumulative_cases'], 
        line_width = 2, color = "green")
p.xaxis.axis_label = "Days From Begining"
p.yaxis.axis_label = "Cumulative Cases"
p.title.align = "center"
p.title.text_color = "white"
# show the results
show(p)

# %%
Venezuela_MM = pd.read_csv (r'Venezuela_MM.csv')
Venezuela_MM.drop(['Country_code', 'Country', 'WHO_region','New_cases','New_deaths','Cumulative_deaths'], 
                    axis='columns',  inplace=True)
Venezuela_MM = pd.DataFrame(Venezuela_MM)
Venezuela_MM['Days_reported'] = Venezuela_MM.index

# %%
Venezuela_MM_filtered = Venezuela_MM[(Venezuela_MM["Cumulative_cases"] >= 1) & (Venezuela_MM["Cumulative_cases"] <= 100)]
Venezuela_MM_filtered_1 = Venezuela_MM[(Venezuela_MM["Cumulative_cases"] >= 1) & (Venezuela_MM["Cumulative_cases"] <= 500)]
Venezuela_MM_filtered
# Out:
#    Date_reported  Cumulative_cases  Days_reported
# 71     3/14/2020                 6             71
# 72     3/15/2020                21             72
# 73     3/16/2020                21             73
# 74     3/17/2020                37             74
# 75     3/18/2020                40             75
# 76     3/19/2020                40             76
# 77     3/20/2020                40             77
# 78     3/21/2020                40             78
# 79     3/22/2020                40             79
# 80     3/23/2020                70             80
# 81     3/24/2020                77             81
# 82     3/25/2020                77             82
# 83     3/26/2020                91             83
# 84     3/27/2020                91             84

# %%
# create figure
p = figure(title="Raw Data For Venezuela",plot_width = 800, plot_height = 400)
   
# add a line renderer
p.line(Venezuela_MM['Days_reported'], Venezuela_MM['Cumulative_cases'], 
        line_width = 2, color = "red")
p.xaxis.axis_label = "Days From Begining"
p.yaxis.axis_label = "Cumulative Cases"
p.title.align = "center"
p.title.text_color = "white"
# show the results
show(p)

# %%
Philippines_MM_scaled = Philippines_MM['Cumulative_cases']/111448385
Afghanistan_MM_scaled = Afghanistan_MM['Cumulative_cases']/40046774
Venezuela_MM_scaled = Venezuela_MM['Cumulative_cases']/28332594
Philippines_MM_scaled = pd.DataFrame(Philippines_MM_scaled)
Afghanistan_MM_scaled = pd.DataFrame(Afghanistan_MM_scaled)
Venezuela_MM_scaled = pd.DataFrame(Venezuela_MM_scaled)


# view normalized data 
display(Philippines_MM_scaled)
display(Afghanistan_MM_scaled)
display(Venezuela_MM_scaled)
# Out:
#      Cumulative_cases
# 0            0.000000
# 1            0.000000
# 2            0.000000
# 3            0.000000
# 4            0.000000
# ..                ...
# 622          0.020484
# 623          0.020674
# 624          0.020856
# 625          0.021063
# 626          0.021236
#
# [627 rows x 1 columns]
#      Cumulative_cases
# 0            0.000000
# 1            0.000000
# 2            0.000000
# 3            0.000000
# 4            0.000000
# ..                ...
# 622          0.003855
# 623          0.003858
# 624          0.003859
# 625          0.003859
# 626          0.003860
#
# [627 rows x 1 columns]
#      Cumulative_cases
# 0            0.000000
# 1            0.000000
# 2            0.000000
# 3            0.000000
# 4            0.000000
# ..                ...
# 622          0.012344
# 623          0.012381
# 624          0.012426
# 625          0.012473
# 626          0.012503
#
# [627 rows x 1 columns]

# %%
Philippines_MM = pd.concat([Philippines_MM['Date_reported'], Philippines_MM_scaled], axis=1)
Philippines_MM
# Out:
#     Date_reported  Cumulative_cases
# 0        1/3/2020          0.000000
# 1        1/4/2020          0.000000
# 2        1/5/2020          0.000000
# 3        1/6/2020          0.000000
# 4        1/7/2020          0.000000
# ..            ...               ...
# 622     9/16/2021          0.020484
# 623     9/17/2021          0.020674
# 624     9/18/2021          0.020856
# 625     9/19/2021          0.021063
# 626     9/20/2021          0.021236
#
# [627 rows x 2 columns]

# %%
Philippines_MM.rename(columns = {'Cumulative_cases':'Philippines_CC'}, inplace = True)

# %%
Afghanistan_MM = pd.concat([Afghanistan_MM['Date_reported'], Afghanistan_MM_scaled], axis=1)
Afghanistan_MM
# Out:
#     Date_reported  Cumulative_cases
# 0        1/3/2020          0.000000
# 1        1/4/2020          0.000000
# 2        1/5/2020          0.000000
# 3        1/6/2020          0.000000
# 4        1/7/2020          0.000000
# ..            ...               ...
# 622     9/16/2021          0.003855
# 623     9/17/2021          0.003858
# 624     9/18/2021          0.003859
# 625     9/19/2021          0.003859
# 626     9/20/2021          0.003860
#
# [627 rows x 2 columns]

# %%
Afghanistan_MM.rename(columns = {'Cumulative_cases':'Afghanistan_CC'}, inplace = True)
Afghanistan_MM_1 = Afghanistan_MM.drop(['Date_reported'], axis = 1)

# %%
Venezuela_MM = pd.concat([Venezuela_MM['Date_reported'], Venezuela_MM_scaled], axis=1)

# %%
Venezuela_MM.rename(columns = {'Cumulative_cases':'Venezuela_CC'}, inplace = True)
Venezuela_MM_1=Venezuela_MM.drop(['Date_reported'], axis = 1)

# %%
Cumulative_cases_3C = pd.concat([Philippines_MM,Afghanistan_MM_1,Venezuela_MM_1], axis=1)

Cumulative_cases_3C=pd.DataFrame(Cumulative_cases_3C)
Cumulative_cases_3C = Cumulative_cases_3C.assign(Days=lambda x: x.index+1)
Cumulative_cases_3C
# Out:
#     Date_reported  Philippines_CC  Afghanistan_CC  Venezuela_CC  Days
# 0        1/3/2020        0.000000        0.000000      0.000000     1
# 1        1/4/2020        0.000000        0.000000      0.000000     2
# 2        1/5/2020        0.000000        0.000000      0.000000     3
# 3        1/6/2020        0.000000        0.000000      0.000000     4
# 4        1/7/2020        0.000000        0.000000      0.000000     5
# ..            ...             ...             ...           ...   ...
# 622     9/16/2021        0.020484        0.003855      0.012344   623
# 623     9/17/2021        0.020674        0.003858      0.012381   624
# 624     9/18/2021        0.020856        0.003859      0.012426   625
# 625     9/19/2021        0.021063        0.003859      0.012473   626
# 626     9/20/2021        0.021236        0.003860      0.012503   627
#
# [627 rows x 5 columns]

# %%
fig = figure(title="Normalized Data",plot_width=600,plot_height=400)
fig.line(Cumulative_cases_3C['Days'],Cumulative_cases_3C['Philippines_CC'], legend="Philippines",
         line_width=2, color="green")
fig.line(Cumulative_cases_3C['Days'],Cumulative_cases_3C['Afghanistan_CC'],
        legend="Afghanistan",line_width=2, color="blue")
fig.line(Cumulative_cases_3C['Days'],Cumulative_cases_3C['Venezuela_CC'],
         legend="Venezuela",line_width=2, color="red")
fig.xaxis.axis_label = "Days From Begining"
fig.yaxis.axis_label = "Cumulative Cases"
fig.title.align = "center"
fig.title.text_color = "Black"
show(fig)

# %%
Cumulative_cases_3C = Cumulative_cases_3C.loc[Cumulative_cases_3C['Days'] > 100]

# %%
Cumulative_cases_3C
# Out:
#     Date_reported  Philippines_CC  Afghanistan_CC  Venezuela_CC  Days
# 100     4/12/2020        0.000040        0.000014      0.000006   101
# 101     4/13/2020        0.000042        0.000015      0.000006   102
# 102     4/14/2020        0.000044        0.000017      0.000006   103
# 103     4/15/2020        0.000047        0.000019      0.000006   104
# 104     4/16/2020        0.000049        0.000020      0.000007   105
# ..            ...             ...             ...           ...   ...
# 622     9/16/2021        0.020484        0.003855      0.012344   623
# 623     9/17/2021        0.020674        0.003858      0.012381   624
# 624     9/18/2021        0.020856        0.003859      0.012426   625
# 625     9/19/2021        0.021063        0.003859      0.012473   626
# 626     9/20/2021        0.021236        0.003860      0.012503   627
#
# [527 rows x 5 columns]

# %%
Cumulative_cases_3C['Philippines_CC_log'] = np.log(Cumulative_cases_3C['Philippines_CC'])
Cumulative_cases_3C['Afghanistan_CC_log'] = np.log(Cumulative_cases_3C['Afghanistan_CC'])
Cumulative_cases_3C['Venezuela_CC_log'] = np.log(Cumulative_cases_3C['Venezuela_CC'])
# Out:
# <ipython-input-23-bf6f0f93f93f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cumulative_cases_3C['Philippines_CC_log'] = np.log(Cumulative_cases_3C['Philippines_CC'])
# <ipython-input-23-bf6f0f93f93f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cumulative_cases_3C['Afghanistan_CC_log'] = np.log(Cumulative_cases_3C['Afghanistan_CC'])
# <ipython-input-23-bf6f0f93f93f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Cumulative_cases_3C.head()
# Out:
#     Date_reported  Philippines_CC  Afghanistan_CC  Venezuela_CC  Days  \
# 100     4/12/2020        0.000040        0.000014      0.000006   101
# 101     4/13/2020        0.000042        0.000015      0.000006   102
# 102     4/14/2020        0.000044        0.000017      0.000006   103
# 103     4/15/2020        0.000047        0.000019      0.000006   104
# 104     4/16/2020        0.000049        0.000020      0.000007   105
#
#      Philippines_CC_log  Afghanistan_CC_log  Venezuela_CC_log
# 100          -10.133369          -11.186591        -12.017860
# 101          -10.084880          -11.097030        -12.017860
# 102          -10.025572          -11.005772        -11.961026
# 103           -9.968245          -10.859168        -11.961026
# 104           -9.925151          -10.828475        -11.896833

# %%
Cumulative_cases_3C.tail()
# Out:
#     Date_reported  Philippines_CC  Afghanistan_CC  Venezuela_CC  Days  \
# 622     9/16/2021        0.020484        0.003855      0.012344   623
# 623     9/17/2021        0.020674        0.003858      0.012381   624
# 624     9/18/2021        0.020856        0.003859      0.012426   625
# 625     9/19/2021        0.021063        0.003859      0.012473   626
# 626     9/20/2021        0.021236        0.003860      0.012503   627
#
#      Philippines_CC_log  Afghanistan_CC_log  Venezuela_CC_log
# 622           -3.888101           -5.558509         -4.394604
# 623           -3.878854           -5.557693         -4.391566
# 624           -3.870093           -5.557402         -4.387981
# 625           -3.860220           -5.557357         -4.384165
# 626           -3.852044           -5.557059         -4.381796

# %%
# import modules
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import row
from bokeh.io import curdoc
# output to notebook
output_notebook()
  
# create figure
p = figure(title = "Logarithmic Graph for Philippiness",plot_width = 800, plot_height = 400)
from bokeh.io import curdoc
curdoc().theme = 'dark_minimal'
   
# add a line renderer
p.line(Cumulative_cases_3C['Days'], Cumulative_cases_3C['Philippines_CC_log'], 
        line_width = 2, color = "green")
p.xaxis.axis_label = "Days From Begining"
p.yaxis.axis_label = "Normalised Cumulative Cases"
p.title.align = "center"
p.title.text_color = "white"
# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1648">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="faacc845-8744-4fc0-a4a1-342a02a45b78" data-root-id="1649"></div>

# %%
# import modules
from bokeh.plotting import figure, output_notebook, show
from bokeh.io import curdoc
curdoc().theme = 'dark_minimal'
# output to notebook
output_notebook()
  
# create figure
p = figure(title = "Logarithmic Graph for Afghanistan",plot_width = 800, plot_height = 400)
   
# add a line renderer
p.line(Cumulative_cases_3C['Days'], Cumulative_cases_3C['Afghanistan_CC_log'], 
        line_width = 2, color = "green")
p.xaxis.axis_label = "Days From Begining"
p.yaxis.axis_label = "Normalised Cumulative Cases"
p.title.align = "center"
p.title.text_color = "white"
# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1747">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e6c08a36-9d7f-4794-8dd8-f861cc6e292f" data-root-id="1748"></div>

# %%
# import modules
from bokeh.plotting import figure, output_notebook, show
from bokeh.io import curdoc
curdoc().theme = 'dark_minimal'  
# output to notebook
output_notebook()
  
# create figure
p = figure(title = "Logarithmic Graph for Venezuela",plot_width = 800, plot_height = 400)
   
# add a line renderer
p.line(Cumulative_cases_3C['Days'], Cumulative_cases_3C['Venezuela_CC_log'], 
        line_width = 2, color = "green")
p.xaxis.axis_label = "Days From Begining"
p.yaxis.axis_label = "Normalised Cumulative Cases"
p.title.align = "center"
p.title.text_color = "white"
# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1856">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="a79dffb7-2f14-445f-a419-fa418e71110a" data-root-id="1857"></div>

# %%
Cumulative_cases_3C
# Out:
#     Date_reported  Philippines_CC  Afghanistan_CC  Venezuela_CC  Days  \
# 100     4/12/2020        0.000040        0.000014      0.000006   101
# 101     4/13/2020        0.000042        0.000015      0.000006   102
# 102     4/14/2020        0.000044        0.000017      0.000006   103
# 103     4/15/2020        0.000047        0.000019      0.000006   104
# 104     4/16/2020        0.000049        0.000020      0.000007   105
# ..            ...             ...             ...           ...   ...
# 622     9/16/2021        0.020484        0.003855      0.012344   623
# 623     9/17/2021        0.020674        0.003858      0.012381   624
# 624     9/18/2021        0.020856        0.003859      0.012426   625
# 625     9/19/2021        0.021063        0.003859      0.012473   626
# 626     9/20/2021        0.021236        0.003860      0.012503   627
#
#      Philippines_CC_log  Afghanistan_CC_log  Venezuela_CC_log
# 100          -10.133369          -11.186591        -12.017860
# ...

# %%
P_w_1 = Cumulative_cases_3C[(Cumulative_cases_3C["Days"] >= 100) & (Cumulative_cases_3C["Days"] <= 160)]
P_w_2 = Cumulative_cases_3C[(Cumulative_cases_3C["Days"] >= 160) & (Cumulative_cases_3C["Days"] <= 200)]
P_w_3 = Cumulative_cases_3C[(Cumulative_cases_3C["Days"] >= 100) & (Cumulative_cases_3C["Days"] <= 200)]

# %%
p1 = figure(title = "Philippines Wave-1",plot_width=450, plot_height=450)
p1.line(P_w_1['Days'], P_w_1['Philippines_CC_log'], 
        line_width = 2, color = "green")

p2 = figure(title = "Philippines Wave-2",plot_width=450, plot_height=450)
p2.line(P_w_2['Days'], P_w_2['Philippines_CC_log'], 
        line_width = 2, color = "green")

p3 = figure(title = "Philippines Wave-3",plot_width=450, plot_height=450)
p3.line(P_w_3['Days'], P_w_3['Philippines_CC_log'], 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"
show(row(p1,p2,p3))
# Out:
#   <div class="bk-root" id="8554d750-bd44-4b71-876f-df7f465a4924" data-root-id="2089"></div>

# %%
A_w_1 = Cumulative_cases_3C[(Cumulative_cases_3C["Days"] >= 100) & (Cumulative_cases_3C["Days"] <= 120)]
A_w_2 = Cumulative_cases_3C[(Cumulative_cases_3C["Days"] >= 120) & (Cumulative_cases_3C["Days"] <= 160)]
A_w_3 = Cumulative_cases_3C[(Cumulative_cases_3C["Days"] >= 100) & (Cumulative_cases_3C["Days"] <= 160)]

# %%
p1 = figure(title = "Afghanistan Wave-1",plot_width=450, plot_height=450)
p1.line(A_w_1['Days'], A_w_1['Afghanistan_CC_log'], 
        line_width = 2, color = "green")
p2 = figure(title = "Afghanistan Wave-2",plot_width=450, plot_height=450)
p2.line(A_w_2['Days'], A_w_2['Afghanistan_CC_log'], 
        line_width = 2, color = "green")
p3 = figure(title = "Afghanistan Wave-3",plot_width=450, plot_height=450)
p3.line(A_w_3['Days'], A_w_3['Afghanistan_CC_log'], 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"


show(row(p1,p2,p3))
# Out:
#   <div class="bk-root" id="3147f4a5-c4fc-4795-b8d3-73a024c4326a" data-root-id="2414"></div>

# %%
v_w_1 = Cumulative_cases_3C[(Cumulative_cases_3C["Days"] >= 100) & (Cumulative_cases_3C["Days"] <= 120)]
v_w_2 = Cumulative_cases_3C[(Cumulative_cases_3C["Days"] >= 120) & (Cumulative_cases_3C["Days"] <= 200)]
v_w_3 = Cumulative_cases_3C[(Cumulative_cases_3C["Days"] >= 200) & (Cumulative_cases_3C["Days"] <= 260)]
v_w_4 = Cumulative_cases_3C[(Cumulative_cases_3C["Days"] >= 100) & (Cumulative_cases_3C["Days"] <= 260)]

# %%
p1 = figure(title = "Venezuela Wave-1",plot_width=450, plot_height=450)
p1.line(v_w_1['Days'], v_w_1['Venezuela_CC_log'], 
        line_width = 2, color = "green")

p2 = figure(title = "Venezuela Wave-2",plot_width=450, plot_height=450)
p2.line(v_w_2['Days'], v_w_2['Venezuela_CC_log'], 
        line_width = 2, color = "green")
p3 = figure(title = "Venezuela Wave-3",plot_width=450, plot_height=450)
p3.line(v_w_3['Days'], v_w_3['Venezuela_CC_log'], 
        line_width = 2, color = "green")
p4 = figure(title = "Venezuela Wave-4",plot_width=450, plot_height=450)
p4.line(v_w_4['Days'], v_w_4['Venezuela_CC_log'], 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"
p4.xaxis.axis_label = "Days From Begining"
p4.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"
p4.title.align = "center"
p4.title.text_color = "white"
show(row(p1,p2,p3,p4))
# Out:
#   <div class="bk-root" id="e82e50c8-1a98-4eea-ab13-e78ce1e5cd08" data-root-id="2807"></div>

# %%
P_w_1_n=pd.DataFrame(P_w_1)
P_w_2_n=pd.DataFrame(P_w_2)
P_w_3_n=pd.DataFrame(P_w_3)
A_w_1_n=pd.DataFrame(A_w_1)
A_w_2_n=pd.DataFrame(A_w_2)
A_w_3_n=pd.DataFrame(A_w_3)
v_w_1_n=pd.DataFrame(v_w_1)
v_w_2_n=pd.DataFrame(v_w_2)
v_w_3_n=pd.DataFrame(v_w_3)
v_w_4_n=pd.DataFrame(v_w_4)

# %%
P_w_1_n['Days'] = P_w_1_n['Days']-101
P_w_2_n['Days'] = P_w_2_n['Days']-161
P_w_3_n['Days'] = P_w_3_n['Days']-101
A_w_1_n['Days'] = A_w_1_n['Days']-101
A_w_2_n['Days'] = A_w_2_n['Days']-121
A_w_3_n['Days'] = A_w_3_n['Days']-101
v_w_1_n['Days'] = v_w_1_n['Days']-101
v_w_2_n['Days'] = v_w_2_n['Days']-121
v_w_3_n['Days'] = v_w_3_n['Days']-201
v_w_4_n['Days'] = v_w_4_n['Days']-101

# %%
p1 = figure(title = "Philippines Wave-1",plot_width=450, plot_height=450)
p1.line(P_w_1['Days'], P_w_1['Philippines_CC_log'], 
        line_width = 2, color = "green")

p2 = figure(title = "Philippines Wave-2",plot_width=450, plot_height=450)
p2.line(P_w_2['Days'], P_w_2['Philippines_CC_log'], 
        line_width = 2, color = "green")
p3 = figure(title = "Philippines Wave-3",plot_width=450, plot_height=450)
p3.line(P_w_3['Days'], P_w_3['Philippines_CC_log'], 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"
show(row(p1,p2,p3))
# Out:
#   <div class="bk-root" id="1eac190a-35f7-4463-a104-a1060cf34e3c" data-root-id="3252"></div>

# %%
p1 = figure(title = "Afghanistan Wave-1",plot_width=450, plot_height=450)
p1.line(A_w_1['Days'], A_w_1['Afghanistan_CC_log'], 
        line_width = 2, color = "green")
p2 = figure(title = "Afghanistan Wave-2",plot_width=450, plot_height=450)
p2.line(A_w_2['Days'], A_w_2['Afghanistan_CC_log'], 
        line_width = 2, color = "green")
p3 = figure(title = "Afghanistan Wave-3",plot_width=450, plot_height=450)
p3.line(A_w_3['Days'], A_w_3['Afghanistan_CC_log'], 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"

p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"

show(row(p1,p2,p3))
# Out:
#   <div class="bk-root" id="fb48c55c-f2cb-4a4b-b3ab-cd8960399082" data-root-id="3677"></div>

# %%
p1 = figure(title = "Venezuela Wave-1",plot_width=450, plot_height=450)
p1.line(v_w_1['Days'], v_w_1['Venezuela_CC_log'], 
        line_width = 2, color = "green")

p2 = figure(title = "Venezuela Wave-2",plot_width=450, plot_height=450)
p2.line(v_w_2['Days'], v_w_2['Venezuela_CC_log'], 
        line_width = 2, color = "green")
p3 = figure(title = "Venezuela Wave-3",plot_width=450, plot_height=450)
p3.line(v_w_3['Days'], v_w_3['Venezuela_CC_log'], 
        line_width = 2, color = "green")
p4 = figure(title = "Venezuela Wave-4",plot_width=450, plot_height=450)
p4.line(v_w_4['Days'], v_w_4['Venezuela_CC_log'], 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"
p4.xaxis.axis_label = "Days From Begining"
p4.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"
p4.title.align = "center"
p4.title.text_color = "white"
show(row(p1,p2,p3,p4))
# Out:
#   <div class="bk-root" id="33a74dfd-c9a7-4974-948e-b3f3c2286e73" data-root-id="4170"></div>

# %%
P_w_1 = Cumulative_cases_3C[(Cumulative_cases_3C["Days"] >= 100) & (Cumulative_cases_3C["Days"] <= 160)]
P_w_2 = Cumulative_cases_3C[(Cumulative_cases_3C["Days"] >= 160) & (Cumulative_cases_3C["Days"] <= 200)]
P_w_3 = Cumulative_cases_3C[(Cumulative_cases_3C["Days"] >= 100) & (Cumulative_cases_3C["Days"] <= 200)]

# %%
xp1 = P_w_1['Days']
yp1 = P_w_1['Philippines_CC_log']
yp11 = P_w_1['Philippines_CC']
z,cov = np.polyfit(xp1,yp1,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.025412973001086272 -12.571147133884459

# %%
exp_P_w_1_n = np.exp(-12.571147133884459+xp1*(0.025412973001086272))
error_P_w_1_n = yp11 - exp_P_w_1_n
KP1 = yp11*(1+exp_P_w_1_n)/exp_P_w_1_n
ln_pP = np.log(abs(yp11/0.825022-yp11))

# %%
p1 = figure(title = "Exponential graph for Phillippines Wave-1",plot_width=450, plot_height=450)
p1.line(P_w_1_n['Days'], exp_P_w_1_n, 
        line_width = 2, color = "green")

p2 = figure(title = "Error graph for Phillippines Wave-1",plot_width=450, plot_height=450)
p2.line(P_w_1_n['Days'], error_P_w_1_n, 
        line_width = 2, color = "green")
p3 = figure(title = "K graph for Phillippines Wave-1",plot_width=450, plot_height=450)
p3.line(P_w_1_n['Days'], KP1, 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"
show(row(p1,p2,p3))
# Out:
#   <div class="bk-root" id="2374bff5-0cb0-44e2-971f-6febacb7ac2d" data-root-id="4715"></div>

# %%
z,cov = np.polyfit(xp1,ln_pP,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.025412973001086272 -14.121896934795156

# %%
exp_P_w_11_n = np.exp(-14.121896934795156+xp1*0.025412973001086272)
logistic_model= 0.879073*exp_P_w_11_n/(1+exp_P_w_11_n)
p1 = figure(title = "Logistic Growth for Phillippines Wave-1",plot_width=450, plot_height=450)
p1.line(P_w_1_n['Days'], exp_P_w_11_n, 
            line_width = 2, color = "green",legend="Observed")
#p2 = figure(title = "Logistic Model for Phillippines Wave-1",plot_width=450, plot_height=450)
p1.line(P_w_1_n['Days'], logistic_model, 
        line_width = 2, color = "red",legend="Predicted")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p1.legend.location = 'top_left'
show(p1)
# Out:
# ...
#   <div class="bk-root" id="f4d0a149-7aea-4a36-8fc7-e1f657a550a3" data-root-id="5126"></div>

# %%
xp2 = P_w_2['Days']
yp2 = P_w_2['Philippines_CC_log']
yp22 = P_w_2['Philippines_CC']
z,cov = np.polyfit(xp2,yp2,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.02726535363565442 -12.891735486902737

# %%
exp_P_w_2_n = np.exp(-12.891735486902737+xp2*0.02726535363565442)
error_P_w_2_n = yp22 - exp_P_w_2_n
KP2 = yp22*(1+exp_P_w_2_n)/exp_P_w_2_n
ln_pP2 = np.log(abs(yp22/0.949904-yp22))

# %%
p1 = figure(title = "Exponential graph for Phillippines Wave-2",plot_width=450, plot_height=450)
p1.line(P_w_2_n['Days'], exp_P_w_2_n, 
        line_width = 2, color = "green")

p2 = figure(title = "Error graph for Phillippines Wave-2",plot_width=450, plot_height=450)
p2.line(P_w_2_n['Days'], error_P_w_2_n, 
        line_width = 2, color = "green")
p3 = figure(title = "K graph for Phillippines Wave-2",plot_width=450, plot_height=450)
p3.line(P_w_2_n['Days'], KP2, 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"
show(row(p1,p2,p3))
# Out:
#   <div class="bk-root" id="e23e2652-ba79-4cee-b33b-b0837fa3916e" data-root-id="5640"></div>

# %%
z,cov = np.polyfit(xp2,ln_pP2,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.027265353635654407 -15.83415524917553

# %%
exp_P_w_22_n = np.exp(-15.83415524917553+xp2*0.027265353635654407)
logistic_model= 1.044257*exp_P_w_22_n/(1+exp_P_w_22_n)
p1 = figure(title = "Logistic Growth for Phillippines Wave-2",plot_width=450, plot_height=450)
p1.line(P_w_2_n['Days'], exp_P_w_22_n, 
        line_width = 2, color = "green",legend="Observed")
#p2 = figure(title = "Logistic Model graph for Phillippines Wave-2",plot_width=450, plot_height=450)
p1.line(P_w_2_n['Days'], logistic_model, 
        line_width = 2, color = "red",legend="Predicted")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
#p2.xaxis.axis_label = "Days From Begining"
#p2.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p1.legend.location = 'top_left'
#p2.title.align = "center"
#p2.title.text_color = "white"
show(p1)
# Out:
# ...
#   <div class="bk-root" id="33d633a4-acbd-4760-8869-261848ad0b71" data-root-id="6093"></div>

# %%
xp3 = P_w_3['Days']
yp3 = P_w_3['Philippines_CC_log']
yp33 = P_w_3['Philippines_CC']
z,cov = np.polyfit(xp3,yp3,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.02572480355535926 -12.613002175560322

# %%
exp_P_w_3_n = np.exp(-12.613002175560322+xp3*0.02572480355535926)
error_P_w_3_n = yp33 - exp_P_w_3_n
KP3 = yp33*(1+exp_P_w_3_n)/exp_P_w_3_n
ln_pP3 = np.log(abs(yp33/0.949904-yp33))

# %%
p1 = figure(title = "Exponential graph for Phillippines Wave-3",plot_width=450, plot_height=450)
p1.line(P_w_3['Days'], exp_P_w_3_n, 
        line_width = 2, color = "green")

p2 = figure(title = "Error graph for Phillippines Wave-3",plot_width=450, plot_height=450)
p2.line(P_w_3['Days'], error_P_w_3_n, 
        line_width = 2, color = "green")
p3 = figure(title = "K graph for Phillippines Wave-3",plot_width=450, plot_height=450)
p3.line(P_w_3['Days'], KP3, 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"
show(row(p1,p2,p3))
# Out:
#   <div class="bk-root" id="401a4ff6-aa82-4665-9712-83e760159c58" data-root-id="6649"></div>

# %%
z,cov = np.polyfit(xp3,ln_pP3,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.025724803555359263 -15.55542193783312

# %%
exp_P_w_33_n = np.exp(-15.55542193783312+xp3*0.025724803555359263)
logistic_model= 1.044257*exp_P_w_33_n/(1+exp_P_w_33_n)
p1 = figure(title = "Logistic Growth for Phillippines Wave-3",plot_width=450, plot_height=450)
p1.line(P_w_3['Days'], exp_P_w_33_n, 
        line_width = 2, color = "green",legend="Observed")
#p2 = figure(title = "Logistic Model graph for Phillippines Wave-2",plot_width=450, plot_height=450)
p1.line(P_w_3['Days'], logistic_model, 
        line_width = 2, color = "red",legend="Predicted")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
#p2.xaxis.axis_label = "Days From Begining"
#p2.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p1.legend.location = 'top_left'
#p2.title.align = "center"
#p2.title.text_color = "white"
show(p1)
# Out:
# ...
#   <div class="bk-root" id="cf020e9c-d3f6-4e47-9ae4-f9f450f2996e" data-root-id="11630"></div>

# %%
xa1 = A_w_1_n['Days']
ya1 = A_w_1_n['Afghanistan_CC_log']
ya11 = A_w_1_n['Afghanistan_CC']
z,cov = np.polyfit(xa1,ya1,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.06532866047336182 -11.130537313711548

# %%
exp_A_w_1_n = np.exp(-11.130537313711548+xa1*0.06532866047336182)
error_A_w_1_n = ya11 - exp_A_w_1_n
Ka1 = ya11*(1+exp_A_w_1_n)/exp_A_w_1_n
ln_pA1 = np.log(abs(ya11/0.484110-ya11))

# %%
p1 = figure(title = "Exponential graph for Afghanistan Wave-1",plot_width=450, plot_height=450)
p1.line(A_w_1['Days'], exp_A_w_1_n, 
        line_width = 2, color = "green")

p2 = figure(title = "Error graph for Afghanistan Wave-1",plot_width=450, plot_height=450)
p2.line(A_w_1['Days'], error_A_w_1_n, 
        line_width = 2, color = "green")
p3 = figure(title = "K graph for Afghanistan Wave-1",plot_width=450, plot_height=450)
p3.line(A_w_1['Days'], Ka1, 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"
show(row(p1,p2,p3))
# Out:
#   <div class="bk-root" id="2b10869c-5b45-4641-af67-900c05d4a8fb" data-root-id="19234"></div>

# %%
z,cov = np.polyfit(xa1,ln_pA1,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.06532866047336168 -11.066955902871653

# %%
exp_A_w_11_n = np.exp(-11.066955902871653+xa1*0.06532866047336168)
logistic_model_A1= 0.484110*exp_A_w_11_n/(1+exp_A_w_11_n)
p1 = figure(title = "Logistic Growth for Aghanistan Wave-1",plot_width=450, plot_height=450)
p1.line(A_w_1_n['Days'], exp_A_w_11_n, 
        line_width = 2, color = "green",legend="Observed")
#p2 = figure(title = "Logistic Model graph for Phillippines Wave-2",plot_width=450, plot_height=450)
p1.line(A_w_1_n['Days'], logistic_model_A1, 
        line_width = 2, color = "red",legend="Predicted")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
#p2.xaxis.axis_label = "Days From Begining"
#p2.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p1.legend.location = 'top_left'
#p2.title.align = "center"
#p2.title.text_color = "white"
show(p1)
# Out:
# ...
#   <div class="bk-root" id="75765d66-2cd2-404c-94e9-8ad4f80f4e73" data-root-id="20909"></div>

# %%
xa2 = A_w_2_n['Days']
ya2 = A_w_2_n['Afghanistan_CC_log']
ya22 = A_w_2_n['Afghanistan_CC']
z,cov = np.polyfit(xa2,ya2,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.06019478020924617 -9.659167609756963

# %%
exp_A_w_2_n = np.exp(-9.659167609756963+xa2*0.06019478020924617)
error_A_w_2_n = ya22 - exp_A_w_2_n
Ka2 = ya22*(1+exp_A_w_2_n)/exp_A_w_2_n
ln_pA2 = np.log(abs(ya22/0.961557-ya22))

# %%
p1 = figure(title = "Exponential graph for Afghanistan Wave-2",plot_width=450, plot_height=450)
p1.line(A_w_2_n['Days'], exp_A_w_2_n, 
        line_width = 2, color = "green")

p2 = figure(title = "Error graph for Afghanistan Wave-2",plot_width=450, plot_height=450)
p2.line(A_w_2_n['Days'], error_A_w_2_n, 
        line_width = 2, color = "green")
p3 = figure(title = "K graph for Afghanistan Wave-2",plot_width=450, plot_height=450)
p3.line(A_w_2_n['Days'], Ka2, 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"
show(row(p1,p2,p3))
# Out:
#   <div class="bk-root" id="7eafe11d-8494-44c6-8d68-d9f7da332b86" data-root-id="21867"></div>

# %%
z,cov = np.polyfit(xa2,ln_pA2,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.060194780209246075 -12.878544830638642

# %%
exp_A_w_22_n = np.exp(-12.878544830638642+xa2*0.060194780209246075)
logistic_model_A2= 0.961557*exp_A_w_22_n/(1+exp_A_w_22_n)
p1 = figure(title = "Logistic Growth for Aghanistan Wave-2",plot_width=450, plot_height=450)
p1.line(A_w_2['Days'], exp_A_w_22_n, 
        line_width = 2, color = "green",legend="Observed")
#p2 = figure(title = "Logistic Model graph for Phillippines Wave-2",plot_width=450, plot_height=450)
p1.line(A_w_2['Days'], logistic_model_A2, 
        line_width = 2, color = "red",legend="Predicted")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
#p2.xaxis.axis_label = "Days From Begining"
#p2.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p1.legend.location = 'top_left'
#p2.title.align = "center"
#p2.title.text_color = "white"
show(p1)
# Out:
# ...
#   <div class="bk-root" id="ba85111f-80ab-447a-b008-2ed667715ce9" data-root-id="23650"></div>

# %%
xa3 = A_w_3_n['Days']
ya3 = A_w_3_n['Afghanistan_CC_log']
ya33 = A_w_3_n['Afghanistan_CC']
z,cov = np.polyfit(xa3,ya3,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.06518565364795466 -11.081473840819365

# %%
exp_A_w_3_n = np.exp(-11.081473840819365+xa3*0.06518565364795466)
error_A_w_3_n = ya33 - exp_A_w_3_n
Ka3 = ya33*(1+exp_A_w_3_n)/exp_A_w_3_n
ln_pA3 = np.log(abs(ya33/1.002960-ya33))

# %%
p1 = figure(title = "Exponential graph for Afghanistan Wave-3",plot_width=450, plot_height=450)
p1.line(A_w_3_n['Days'], exp_A_w_3_n, 
        line_width = 2, color = "green")

p2 = figure(title = "Error graph for Afghanistan Wave-3",plot_width=450, plot_height=450)
p2.line(A_w_3_n['Days'], error_A_w_3_n, 
        line_width = 2, color = "green")
p3 = figure(title = "K graph for Afghanistan Wave-3",plot_width=450, plot_height=450)
p3.line(A_w_3_n['Days'], Ka3, 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"

show(row(p1,p2,p3))
# Out:
#   <div class="bk-root" id="19e619bb-22d2-4611-b10b-59a11ad9b856" data-root-id="24662"></div>

# %%
z,cov = np.polyfit(xa3,ln_pA3,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.0651856536479546 -16.906995479291133

# %%
exp_A_w_33_n = np.exp(-16.906995479291133+xa3*0.0651856536479546)
logistic_model_A3= 1.002960*exp_A_w_33_n/(1+exp_A_w_33_n)
p1 = figure(title = "Logistic Growth for Aghanistan Wave-3",plot_width=450, plot_height=450)
p1.line(A_w_3_n['Days'], exp_A_w_33_n, 
        line_width = 2, color = "green",legend="Observed")
#p2 = figure(title = "Logistic Model graph for Phillippines Wave-2",plot_width=450, plot_height=450)
p1.line(A_w_3_n['Days'], logistic_model_A3, 
        line_width = 2, color = "red",legend="Predicted")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
#p2.xaxis.axis_label = "Days From Begining"
#p2.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p1.legend.location = 'top_left'
#p2.title.align = "center"
#p2.title.text_color = "white"
show(p1)
# Out:
# ...
#   <div class="bk-root" id="71532c45-eabb-4161-89d6-6f696031fa7d" data-root-id="29413"></div>

# %%
xv1 = v_w_1_n['Days']
yv1 = v_w_1_n['Venezuela_CC_log']
yv11 = v_w_1_n['Venezuela_CC']
z,cov = np.polyfit(xv1,yv1,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.042128402598849674 -12.043276483555804

# %%
exp_v_w_1_n = np.exp(-12.043276483555804+xv1*0.042128402598849674)
error_v_w_1_n = yv11 - exp_v_w_1_n
KV1 = yv11*(1+exp_v_w_1_n)/exp_v_w_1_n
ln_pv1 = np.log(abs(yv11/1.027555-yv11))

# %%
p1 = figure(title = "Exponential graph for Venezuela Wave-1",plot_width=450, plot_height=450)
p1.line(v_w_1_n['Days'], exp_v_w_1_n, 
        line_width = 2, color = "green")

p2 = figure(title = "Error graph for Venezuela Wave-1",plot_width=450, plot_height=450)
p2.line(v_w_1_n['Days'], error_v_w_1_n, 
        line_width = 2, color = "green")
p3 = figure(title = "K graph for Venezuela Wave-1",plot_width=450, plot_height=450)
p3.line(v_w_1_n['Days'], KV1, 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"
show(row(p1,p2,p3))
# Out:
#   <div class="bk-root" id="1832d1b6-3a92-495f-9b64-333be0daaead" data-root-id="30513"></div>

# %%
z,cov = np.polyfit(xv1,ln_pv1,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.04212840259884989 -15.662029949138956

# %%
exp_v_w_11_n = np.exp(-15.662029949138956+xv1*0.04212840259884989)
logistic_model_v1= 1.027555*exp_v_w_11_n/(1+exp_v_w_11_n)
p1 = figure(title = "Logistic Growth for Venezuela Wave-1",plot_width=450, plot_height=450)
p1.line(v_w_1_n['Days'], exp_v_w_11_n, 
        line_width = 2, color = "green",legend="Observed")
#p2 = figure(title = "Logistic Model graph for Phillippines Wave-2",plot_width=450, plot_height=450)
p1.line(v_w_1_n['Days'], logistic_model_v1, 
        line_width = 2, color = "red",legend="Predicted")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
#p2.xaxis.axis_label = "Days From Begining"
#p2.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p1.legend.location = 'top_left'
#p2.title.align = "center"
#p2.title.text_color = "white"
show(p1)
# Out:
# ...
#   <div class="bk-root" id="bfe834a1-41fb-41d2-b3e8-f150c48f9dba" data-root-id="31552"></div>

# %%
xv2 = v_w_2_n['Days']
yv2 = v_w_2_n['Venezuela_CC_log']
yv22 = v_w_2_n['Venezuela_CC']
z,cov = np.polyfit(xv2,yv2,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.0480051755810643 -11.416225368781388

# %%
exp_v_w_2_n = np.exp((-11.416225368781388)+(xv2*0.0480051755810643))
error_v_w_2_n = yv22 - exp_v_w_2_n
KV2 = (yv22)*(1+exp_v_w_2_n)/exp_v_w_2_n
ln_pv2 = np.log(abs(yv22/0.633724-yv22))

# %%
p1 = figure(title = "Exponential graph for Venezuela Wave-2",plot_width=450, plot_height=450)
p1.line(v_w_2_n['Days'], exp_v_w_2_n, 
        line_width = 2, color = "green")

p2 = figure(title = "Error graph for Venezuela Wave-2",plot_width=450, plot_height=450)
p2.line(v_w_2_n['Days'], error_v_w_2_n, 
        line_width = 2, color = "green")
p3 = figure(title = "K graph for Venezuela Wave-2",plot_width=450, plot_height=450)
p3.line(v_w_2_n['Days'], KV2, 
        line_width = 2, color = "green")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
p2.xaxis.axis_label = "Days From Begining"
p2.yaxis.axis_label = "Normalised Cumulative Cases"
p3.xaxis.axis_label = "Days From Begining"
p3.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p2.title.align = "center"
p2.title.text_color = "white"
p3.title.align = "center"
p3.title.text_color = "white"
show(row(p1,p2,p3))
# Out:
#   <div class="bk-root" id="40786776-cf98-4d80-8fc3-2cdbc3d3b413" data-root-id="32694"></div>

# %%
z,cov = np.polyfit(xv2,ln_pv2,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
# Out:
# 0.04800517558106433 -11.964451749631467

# %%
exp_v_w_22_n = np.exp(-11.964451749631467+xv2*0.04800517558106433)
logistic_model_v2= 0.633724*exp_v_w_22_n/(1+exp_v_w_22_n)
p1 = figure(title = "Logistic Growth for Venezuela Wave-2",plot_width=450, plot_height=450)
p1.line(v_w_2_n['Days'], exp_v_w_22_n, 
        line_width = 2, color = "green",legend="Observed")
#p2 = figure(title = "Logistic Model graph for Phillippines Wave-2",plot_width=450, plot_height=450)
p1.line(v_w_2_n['Days'], logistic_model_v2, 
        line_width = 2, color = "red",legend="Predicted")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
#p2.xaxis.axis_label = "Days From Begining"
#p2.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p1.legend.location = 'top_left'
#p2.title.align = "center"
#p2.title.text_color = "white"
show(p1)
# Out:
# ...
#   <div class="bk-root" id="088ae0d6-46a4-4358-b7a1-c5c540789a1a" data-root-id="33775"></div>

# %%
xv1 = v_w_3_n['Days']
yv1 = v_w_3_n['Venezuela_CC_log']
yv11 = v_w_3_n['Venezuela_CC']
z,cov = np.polyfit(xv1,yv1,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
exp_v_w_1_n = np.exp(-7.662923384232327+xv1*0.028960506600165713)
error_v_w_1_n = yv11 - exp_v_w_1_n
KV1 = yv11*(1+exp_v_w_1_n)/exp_v_w_1_n
ln_pv1 = np.log(abs(yv11/1.027555-yv11))
z,cov = np.polyfit(xv1,ln_pv1,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
xp_v_w_11_n = np.exp(-11.28167684981548+xv1*0.028960506600165553)
logistic_model_v1= 1.027555*exp_v_w_11_n/(1+exp_v_w_11_n)
p1 = figure(title = "Logistic Growth for Venezuela Wave-3",plot_width=450, plot_height=450)
p1.line(v_w_3_n['Days'], exp_v_w_11_n, 
        line_width = 2, color = "green",legend="Observed")
#p2 = figure(title = "Logistic Model graph for Phillippines Wave-2",plot_width=450, plot_height=450)
p1.line(v_w_3_n['Days'], logistic_model_v1, 
        line_width = 2, color = "red",legend="Predicted")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
#p2.xaxis.axis_label = "Days From Begining"
#p2.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p1.legend.location = 'top_left'
#p2.title.align = "center"
#p2.title.text_color = "white"
show(p1)
# Out:
# 0.028960506600165713 -7.662923384232327
# 0.028960506600165553 -11.28167684981548
# ...
#   <div class="bk-root" id="722f5f43-2fa5-4b25-8f57-d55979d54e08" data-root-id="34845"></div>

# %%
xv1 = v_w_4_n['Days']
yv1 = v_w_4_n['Venezuela_CC_log']
yv11 = v_w_4_n['Venezuela_CC']
z,cov = np.polyfit(xv1,yv1,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
exp_v_w_1_n = np.exp(-11.962417087100564+xv1*0.04017459204505269)
error_v_w_1_n = yv11 - exp_v_w_1_n
KV1 = yv11*(1+exp_v_w_1_n)/exp_v_w_1_n
ln_pv1 = np.log(abs(yv11/1.027555-yv11))
z,cov = np.polyfit(xv1,ln_pv1,1,cov=True)
slope = z[0]
intercept = z[1]
print (slope, intercept)
exp_v_w_11_n = np.exp(-15.581170552683725+xv1*0.04017459204505274)
logistic_model_v1= 1.027555*exp_v_w_11_n/(1+exp_v_w_11_n)
p1 = figure(title = "Logistic Growth for Venezuela Wave-4",plot_width=450, plot_height=450)
p1.line(v_w_4_n['Days'], exp_v_w_11_n, 
        line_width = 2, color = "green",legend="Observed")
#p2 = figure(title = "Logistic Model graph for Phillippines Wave-2",plot_width=450, plot_height=450)
p1.line(v_w_4_n['Days'], logistic_model_v1, 
        line_width = 2, color = "red",legend="Predicted")
p1.xaxis.axis_label = "Days From Begining"
p1.yaxis.axis_label = "Normalised Cumulative Cases"
#p2.xaxis.axis_label = "Days From Begining"
#p2.yaxis.axis_label = "Normalised Cumulative Cases"
p1.title.align = "center"
p1.title.text_color = "white"
p1.legend.location = 'top_left'
#p2.title.align = "center"
#p2.title.text_color = "white"
show(p1)
# Out:
# 0.04017459204505269 -11.962417087100564
# 0.04017459204505274 -15.581170552683725
# ...
#   <div class="bk-root" id="0661a962-8292-4aca-a7a4-a45d94ddd849" data-root-id="37021"></div>
